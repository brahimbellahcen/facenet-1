# %%
from face_verification import verification_file
import CONSTANTS

# %%
root = CONSTANTS.root
ducnv = root + '/data/FV_test/ducnv/'
thangnd = root + '/data/FV_test/thangnd/'

# %%
from tensorflow.keras.models import load_model
model = load_model(root + '/model/facenet_keras.h5')
# Out:
# WARNING:tensorflow:No training configuration found in save file: the model was *not* compiled. Compile it manually.

# %%
verification_file(ducnv + 'anh_20173033.png',  ducnv + '4.jpg', model=model, plot=True, thresh=0.4)
# Out:
# 1
